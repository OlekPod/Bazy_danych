# %%
# Wczytanie danych
import pandas as pd
import matplotlib.pyplot as plt
data_final = pd.read_csv("/home/aleksander/Documents/Zajecia_VII/Bazy_danych/laby/Lab2/Analysis_Data/data_final")

# %%
data_final.groupby(['Do you think the "Big One" will occur in your lifetime?','What is your gender?']).size().unstack().plot(kind='bar',stacked=True)
plt.show()

# %%
data_final.groupby(["Have you or anyone in your household taken any precautions for an earthquake (packed an earthquake survival kit, prepared an evacuation plan, etc.)?",'What is your gender?']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
